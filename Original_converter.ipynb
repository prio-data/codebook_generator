# %% [markdown]
# # Transformer
#
# This notebook takes a Markdown file, converts it to Json, produces a Pandas DataFrame, and finally writes a new Markdown file with the information from the Pandas DataFrame.

# %%
# Specifying paths - note these have to be set to conform to individual setups!

# Make the command to call from dropbox! 

Mydropbox = '/Users/chandlerwilliams/Dropbox (ViEWS)/ViEWS/' # Update to your preferred path
localgitpath = '/Users/chandlerwilliams/views3/ViEWS_organization/' # Update to your preferred path

import os
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/chandlerwilliams/views3/ViEWS_organization

# %% [markdown]
# ## From Markdown to Json
#
# This part will use the commands in 'markdown-to-json' to convert a Markdown file into a Json file.
#
# Currently, I ran the commands in the terminal-- it worked, but I might need to import those commands into this notebook.

# %%
# If you do not already have markdown-to-json installed, use the command below to install it. 
# Warning: If you have Python > 3.8 your terminal will not be able to run themd_to_json command.
# If you Python is >3.8 you will have to create a new enviroment which uses Python 3.8
# Run this command to check which Python you have
# !python -V

# If you have Python >3.8 then: 
# (1) create a new conda enviornment 
# (2) Download Python 3.8 
# (3) conda install -c conda-forge tensorflow
# (4) pip install jupyter

# The following command sees what environment you are working in
print (os.environ['CONDA_DEFAULT_ENV'])
# Out:
# Python 3.8.13
# python38

# %%
# If you need to set up a new Python 3.8 environment, you will need to install the following in the environment
#!pip install wheel
#!pip install pandas
#!pip install tabulate

# %%
#If you have not alraedy installed "markdown-to-json" run the pip install command
#!pip install markdown-to-json

#The following command will take the markdown file and produce a json file. 

#!md_to_json -o examplecodebook_sn.json examplecodebook_sn.md
#!md_to_json -o Codebooktest.json Codebooktest.md

# Try with a new file
#!md_to_json -o test.json Model_fatalities002_conflict_history_long_codebook.md
# !md_to_json -o Outputcodebook.json Outputcodebook.md
#!md_to_json -o test12345.json cm_features_codebook.md

# If this command works, nothing should happen in the notebook. But, a new file should appear 
# in your saved files called "codebook.json"

# %% [markdown]
# ## From Json to Pandas DataFrame
#
# This section takes a Json file and creates a Pandas DataFrame.

# %%
import json
import pandas as pd

# %%
# While testing everything, I have simply used my direct path, I will update with a 'call path' command

# This takes the Json file and produces a Pandas DataFrame. Need to: Alter the Short and Long descriptions to fit 
# all of the text (it fits fine in the print(df.to_markdown()) command later)

#df = pd.read_json("/Users/chandlerwilliams/views3/ViEWS_organization/Codebooktest.json", orient = "index")
#df = pd.read_json("/Users/chandlerwilliams/views3/ViEWS_organization/examplecodebook_sn.json", orient = "index")
#df = pd.read_json("/Users/chandlerwilliams/views3/ViEWS_organization/Codebooktest.json", orient = "index")
#df = pd.read_json("/Users/chandlerwilliams/views3/ViEWS_organization/test.json", orient = "index")
df = pd.read_json("/Users/chandlerwilliams/views3/ViEWS_organization/Outputcodebook.json", orient = "index")

#This command sets "Variable ID" to be the Pandas Dataframe index
df = df.set_index('Variable id')

# %%
df
# Out:
#                       Viewser table  \
# Variable ID
# ged_sb_best_sum_nokgi       ged2_cm
# ged_os_best_sum_nokgi       ged2_cm
# ged_ns_best_sum_nokgi       ged2_cm
# wdi_sp_pop_totl              wdi_cy
# acled_sb_fat              acled2_cm
# acled_sb_count            acled2_cm
# acled_os_fat              acled2_cm
# acled_ns_fat              acled2_cm
# acled_prx_count           acled2_cm
# acled_pr_count            acled2_cm
# acled_prx_fat             acled2_cm
# acled_bat_gov_fat         acled2_cm
# acled_bat_reb_fat         acled2_cm
# country.gwcode
# topic_religion             topic_cm
# topic_politics             topic_cm
# topic_sanctions            topic_cm
# topic_life                 topic_cm
# topic_energy               topic_cm
# topic_media                topic_cm
# topic_economics            topic_cm
# topic_health               topic_cm
# topic_china                topic_cm
# topic_foreign              topic_cm
# topic_conflict             topic_cm
# ...

# %%
# This command prints the Pandas DataFrame into a Markdown DataFrame
# For now, I have copy and pasted the output into the next Markdown cell to populate the dataframe

# However, once I learn how I would like the output to autopopulate into a markdown cell
# 

print(df.to_markdown())
# Out:
# | Variable ID           | Viewser table   | Source                                                                                                                                                        | Transformations prior to data ingestion   | Short description                                                                      | Long description                                                                                                                                                                                                                                                                    | Update cycle in ViEWS   | Update cycle from data provider   |
# ...

# %% [markdown]
# | Variable ID           | Viewser table   | Source                                                                                                                                                        | Transformations prior to data ingestion   | Short description                                                                      | Long description                                                                                                                                                                                                                                                                    | Update cycle in ViEWS   | Update cycle from data provider   |
# |:----------------------|:----------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------|:---------------------------------------------------------------------------------------|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:------------------------|:----------------------------------|
# | ged_sb_best_sum_nokgi | ged2_cm         | ucdp_ged                                                                                                                                                      |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     | monthly                 | monthly                           |
# | ged_os_best_sum_nokgi | ged2_cm         | ucdp_ged                                                                                                                                                      |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     | monthly                 | monthly                           |
# | ged_ns_best_sum_nokgi | ged2_cm         | ucdp_ged                                                                                                                                                      |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     | monthly                 | monthly                           |
# | wdi_sp_pop_totl       | wdi_cy          | World Development Indicators                                                                                                                                  |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     | yearly                  | yearly                            |
# | acled_sb_fat          | acled2_cm       | acled                                                                                                                                                         | E.g. time lag, spatial lag, log, none     |                                                                                        |                                                                                                                                                                                                                                                                                     | monthly                 |                                   |
# | acled_sb_count        | acled2_cm       |                                                                                                                                                               |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     | monthly                 | monthly                           |
# | acled_os_fat          | acled2_cm       |                                                                                                                                                               |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     | monthly                 | monthly                           |
# | acled_ns_fat          | acled2_cm       |                                                                                                                                                               |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     | monthly                 | monthly                           |
# | acled_prx_count       | acled2_cm       |                                                                                                                                                               |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     | monthly                 | monthly                           |
# | acled_pr_count        | acled2_cm       |                                                                                                                                                               |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     | monthly                 | monthly                           |
# | acled_prx_fat         | acled2_cm       |                                                                                                                                                               |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     | monthly                 | monthly                           |
# | acled_bat_gov_fat     | acled2_cm       |                                                                                                                                                               |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     | monthly                 | monthly                           |
# | acled_bat_reb_fat     | acled2_cm       |                                                                                                                                                               |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     | monthly                 | monthly                           |
# | country.gwcode        |                 |                                                                                                                                                               |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_religion        | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 0 (religious tensions) in a large text data-base in country/month.      | The share of topic 0 (religious tension) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).       | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_politics        | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 1 (politics) in a large text data-base in country/month.                | The share of topic 1 (politics) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).                |                         |                                   |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_sanctions       | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 2 (diplomacy and sanctions) in a large text data-base in country/month. | The share of topic 2 (diplomacy and sanctions) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews). | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_life            | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 3 (civilian life) in a large text data-base in country/month.           | The share of topic 3 (civilian life) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).           | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_energy          | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 4 (energy and industry) in a large text data-base in country/month.     | The share of topic 4 (energy and industry) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).     | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_media           | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 5 (media and reporting) in a large text data-base in country/month.     | The share of topic 5 (media and reporting) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).     | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_economics       | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 6 (economics) in a large text data-base in country/month.               | The share of topic 6 (economics) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).               | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_health          | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 7 (health and emergencies) in a large text data-base in country/month.  | The share of topic 7 (health and emergencies) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).  | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_china           | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 8 (chinese politics) in a large text data-base in country/month.        | The share of topic 8 (chinese politics) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).        | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_foreign         | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 9 (foreign policy) in a large text data-base in country/month.          | The share of topic 9 (foreign policy) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).          | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_conflict        | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 10 (armed conflict) in a large text data-base in country/month.         | The share of topic 10 (armed conflict) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).         | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_diplomacy       | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 11 (diplomacy) in a large text data-base in country/month.              | The share of topic 11 (diplomacy) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).              | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_power           | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 12 (power and negotiation) in a large text data-base in country/month.  | The share of topic 12 (power and negotiation) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).  | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_sports          | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 13 (sports) in a large text data-base in country/month.                 | The share of topic 13 (sports) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).                 | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |
# | topic_judiciary       | topic_cm        | https://conflictforecast.org/downloads.                                                                                                                       |                                           | Share of topic 14 (judiciary and abuses) in a large text data-base in country/month.   | The share of topic 14 (judiciary and abuses) for a country in each month between 2010 and T in a text data base of more than 4 million documents from three newspapers (New York Times, Washington Post, and the Economist) and two news aggregators (BBC Monitor and LatinNews).   | monthly                 | monthly                           |
# |                       |                 | Reference: Mueller, Hannes and Christoper Rauh (2021) The Hard Problem of Prediction for Conflict Prevention. Cambridge Working Papers in Economics CWPE2103. |                                           |                                                                                        |                                                                                                                                                                                                                                                                                     |                         |                                   |

# %%
# This command takes the Pandas dataframe and translates it back into Json langauge

json_file = df.to_json(orient="index")

# %%
json_file
# Out:
# '{"ged_sb_best_sum_nokgi":{"Viewser table":"ged2_cm","Source":"ucdp_ged","Transformations prior to data ingestion":"","Short description":"","Long description":"","Update cycle in ViEWS":"monthly","Update cycle from data provider":"monthly"},"ged_os_best_sum_nokgi":{"Viewser table":"ged2_cm","Source":"ucdp_ged","Transformations prior to data ingestion":"","Short description":"","Long description":"","Update cycle in ViEWS":"monthly","Update cycle from data provider":"monthly"},"ged_ns_best_sum_nokgi":{"Viewser table":"ged2_cm","Source":"ucdp_ged","Transformations prior to data ingestion":"","Short description":"","Long description":"","Update cycle in ViEWS":"monthly","Update cycle from data provider":"monthly"},"wdi_sp_pop_totl":{"Viewser table":"wdi_cy","Source":"World Development Indicators","Transformations prior to data ingestion":"","Short description":"","Long description":"","Update cycle in ViEWS":"yearly","Update cycle from data provider":"yearly"},"acled_sb_fat":{"Viewser 
# ...

# %% [markdown]
# # <font color='red'>Next Steps</font>
#
# 1. Make a command that pulls files from an assigned path, as opposed to the current direct calls for files

# %%
# Attempting to convert back to Markdown here: 
# I can paste the original markdown
