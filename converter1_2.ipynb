# %%
import pandas as pd
import json
import os
home = os.path.expanduser("~")

print('OS path is set to:', home)
# Out:
# OS path is set to: /Users/chandlerwilliams

# %%
def convert_codebook(file_path):
    with open(file_path, "r") as f:
        lines = f.readlines()

    data = {}
    current_column = None
    current_subcolumn = None

    for line in lines:
        if line.startswith("# "):
            current_column = line.strip()[2:]
            current_subcolumn = None
            data[current_column] = {}
        elif line.startswith("## "):
            current_subcolumn = line.strip()[3:]
            data[current_column][current_subcolumn] = []
        elif current_column is not None and current_subcolumn is not None:
            data[current_column][current_subcolumn].append(line.strip())

    df_data = []
    for column_label, column_data in data.items():
        for subcolumn_label, subcolumn_data in column_data.items():
            df_data.append((column_label, subcolumn_label, "\n".join(subcolumn_data)))

    df = pd.DataFrame(df_data, columns=["Column", "Subcolumn", "Value"])

    df_pivot = df.pivot(index='Column', columns='Subcolumn', values='Value')
    
    return df_pivot

# %%
df_pivot = convert_codebook('cm_features_codebook.md')

# %%
df_pivot
# Out:
# Subcolumn                                           Last accessed License  \
# Column
# ACLED count events with specific actors (acled_...  Every month\n
# ACLED fatalities including several actors (acle...  Every month\n
# ACLED protest event count (acled_pr_count)          Every month\n
# ACLED sum of fatalities for government regain o...  Every month\n
# ACLED sum of fatalities for rebel overtake of t...
# ...                                                           ...     ...
# WDI population in total (wdi_sp_pop_totl)
# WDI prevalence of undrrweight children under 5 ...
# WDI prevelalence of stunting children under 5 i...
# WDI refugee population by origin (wdi_sm_pop_re...
# WDI school enrollment primary (wdi_se_prm_nenr)
#
# Subcolumn                                                                            Long description  \
# Column
# ACLED count events with specific actors (acled_...  Event count of the following: MILITARY VERSUS ...
# ACLED fatalities including several actors (acle...  Number of fatalities from events including the...
# ACLED protest event count (acled_pr_count)          A protest is defined as a public demonstration...
# ACLED sum of fatalities for government regain o...  State forces are defined as collective actors ...
# ACLED sum of fatalities for rebel overtake of t...  Rebel groups are defined as political organiza...
# ...                                                                                               ...
# WDI population in total (wdi_sp_pop_totl)           Total population is based on the de facto defi...
# WDI prevalence of undrrweight children under 5 ...  Prevalence of underweight children is the perc...
# WDI prevelalence of stunting children under 5 i...  Prevalence of stunting is the percentage of ch...
# WDI refugee population by origin (wdi_sm_pop_re...  Refugees are people who are recognized as refu...
# WDI school enrollment primary (wdi_se_prm_nenr)     Net enrollment rate is the ratio of children o...
#
# Subcolumn                                          Periodicity  \
# Column
# ACLED count events with specific actors (acled_...    Annual\n
# ACLED fatalities including several actors (acle...    Annual\n
# ACLED protest event count (acled_pr_count)            Annual\n
# ACLED sum of fatalities for government regain o...    Annual\n
# ACLED sum of fatalities for rebel overtake of t...    Annual\n
# ...                                                        ...
# WDI population in total (wdi_sp_pop_totl)             Annual\n
# WDI prevalence of undrrweight children under 5 ...    Annual\n
# WDI prevelalence of stunting children under 5 i...    Annual\n
# WDI refugee population by origin (wdi_sm_pop_re...    Annual\n
# WDI school enrollment primary (wdi_se_prm_nenr)       Annual\n
#
# Subcolumn                                                                           Short description  \
# Column
# ACLED count events with specific actors (acled_...  Event count including the following actors: mi...
# ACLED fatalities including several actors (acle...  Number of fatalities including the following a...
# ACLED protest event count (acled_pr_count)                                      Protest event count\n
# ACLED sum of fatalities for government regain o...  Sum of fatalities (battle-related deaths) for ...
# ACLED sum of fatalities for rebel overtake of t...  Sum of fatalities (battle related deaths) for ...
# ...                                                                                               ...
# WDI population in total (wdi_sp_pop_totl)                                       Population in total\n
# WDI prevalence of undrrweight children under 5 ...  Prevalence of underweight amongst children und...
# WDI prevelalence of stunting children under 5 i...  Prevalence of stunting amongst children under ...
# WDI refugee population by origin (wdi_sm_pop_re...  Refugee population by country or territory of ...
# WDI school enrollment primary (wdi_se_prm_nenr)                  School enrollment, primary (% net)\n
#
# Subcolumn                                                                                      Source  \
# Column
# ACLED count events with specific actors (acled_...  Raleigh, C., & Dowd, C. (2015). Armed conflict...
# ACLED fatalities including several actors (acle...  Raleigh, C., & Dowd, C. (2015). Armed conflict...
# ACLED protest event count (acled_pr_count)          Raleigh, C., & Dowd, C. (2015). Armed conflict...
# ACLED sum of fatalities for government regain o...  Raleigh, C., & Dowd, C. (2015). Armed conflict...
# ACLED sum of fatalities for rebel overtake of t...  Raleigh, C., & Dowd, C. (2015). Armed conflict...
# ...                                                                                               ...
# WDI population in total (wdi_sp_pop_totl)           World Bank. "Population, total." World Develop...
# WDI prevalence of undrrweight children under 5 ...                     World Development Indicators\n
# WDI prevelalence of stunting children under 5 i...                     World Development Indicators\n
# WDI refugee population by origin (wdi_sm_pop_re...                     World Development Indicators\n
# WDI school enrollment primary (wdi_se_prm_nenr)                        World Development Indicators\n
#
# Subcolumn                                                     Transformations prior to data ingestion  \
# Column
# ACLED count events with specific actors (acled_...  Aggregation of events with interaction codes (...
# ACLED fatalities including several actors (acle...  Aggregation of events with interaction codes (...
# ACLED protest event count (acled_pr_count)
# ACLED sum of fatalities for government regain o...
# ACLED sum of fatalities for rebel overtake of t...
# ...                                                                                               ...
# WDI population in total (wdi_sp_pop_totl)                               clean-up, iso codes created\n
# WDI prevalence of undrrweight children under 5 ...                      clean-up, iso codes created\n
# WDI prevelalence of stunting children under 5 i...                      clean-up, iso codes created\n
# WDI refugee population by origin (wdi_sm_pop_re...                      clean-up, iso codes created\n
# WDI school enrollment primary (wdi_se_prm_nenr)                         clean-up, iso codes created\n
#
# Subcolumn                                                    Variable ID  \
# Column
# ACLED count events with specific actors (acled_...     acled_prx_count\n
# ACLED fatalities including several actors (acle...       acled_prx_fat\n
# ACLED protest event count (acled_pr_count)              acled_pr_count\n
# ACLED sum of fatalities for government regain o...   acled_bat_gov_fat\n
# ACLED sum of fatalities for rebel overtake of t...   acled_bat_reb_fat\n
# ...                                                                  ...
# WDI population in total (wdi_sp_pop_totl)              wdi_sp_pop_totl\n
# WDI prevalence of undrrweight children under 5 ...  wdi_sh_sta_maln_zs\n
# WDI prevelalence of stunting children under 5 i...  wdi_sh_sta_stnt_zs\n
# WDI refugee population by origin (wdi_sm_pop_re...  wdi_sm_pop_refg_or\n
# WDI school enrollment primary (wdi_se_prm_nenr)        wdi_se_prm_nenr\n
#
# Subcolumn                                          Viewser table
# Column
# ACLED count events with specific actors (acled_...   acled2_cm\n
# ACLED fatalities including several actors (acle...   acled2_cm\n
# ACLED protest event count (acled_pr_count)           acled2_cm\n
# ACLED sum of fatalities for government regain o...   acled2_cm\n
# ACLED sum of fatalities for rebel overtake of t...   acled2_cm\n
# ...                                                          ...
# WDI population in total (wdi_sp_pop_totl)               wdi_cy\n
# WDI prevalence of undrrweight children under 5 ...      wdi_cy\n
# WDI prevelalence of stunting children under 5 i...      wdi_cy\n
# WDI refugee population by origin (wdi_sm_pop_re...      wdi_cy\n
# WDI school enrollment primary (wdi_se_prm_nenr)         wdi_cy\n
#
# [159 rows x 9 columns]

# %%
df2 = df_pivot.copy()

# %%
df2 = df_pivot.reset_index().set_index('Variable ID')

# %%
df2.head(50)
# Out:
# Subcolumn                                                         Column  \
# Variable ID
# ged_ns_best_sum_nokgi  UCDP "best estimate" of fatalities from non-st...
# ged_os_best_sum_nokgi  UCDP "best estimate" of fatalities from one-si...
# ged_sb_best_sum_nokgi  UCDP "best estimate" of fatalities from state-...
# wdi_ag_lnd_frst_k2         WDI Forest area (sq. km) (wdi_ag_lnd_frst_k2)
# wdi_ny_gdp_mktp_kd      WDI GDP (constant 2015 US$) (wdi_ny_gdp_mktp_kd)
# wdi_ms_mil_xpnd_gd_zs  WDI Military expenditure (% of GDP) (wdi_ms_mi...
# wdi_ms_mil_xpnd_zs     WDI Military expenditure (% of general governm...
# wdi_dt_oda_odat_pc_zs  WDI Net ODA received per capita (current US$) ...
# wdi_nv_agr_totl_kd     WDI Value added from agriculture in USD (wdi_n...
# wdi_nv_agr_totl_kn     WDI Value added from agriculture in local curr...
# wdi_sp_pop_totl                WDI population in total (wdi_sp_pop_totl)
#
# Subcolumn             Last accessed  \
# Variable ID
# ged_ns_best_sum_nokgi
# ged_os_best_sum_nokgi
# ged_sb_best_sum_nokgi
# wdi_ag_lnd_frst_k2
# wdi_ny_gdp_mktp_kd
# wdi_ms_mil_xpnd_gd_zs
# wdi_ms_mil_xpnd_zs
# wdi_dt_oda_odat_pc_zs
# wdi_nv_agr_totl_kd
# wdi_nv_agr_totl_kn
# wdi_sp_pop_totl
#
# Subcolumn                                                        License  \
# Variable ID
# ged_ns_best_sum_nokgi
# ged_os_best_sum_nokgi
# ged_sb_best_sum_nokgi
# wdi_ag_lnd_frst_k2
# wdi_ny_gdp_mktp_kd
# wdi_ms_mil_xpnd_gd_zs  Use and distribution of these data are subject...
# wdi_ms_mil_xpnd_zs
# wdi_dt_oda_odat_pc_zs
# wdi_nv_agr_totl_kd
# wdi_nv_agr_totl_kn
# wdi_sp_pop_totl
#
# Subcolumn                                               Long description  \
# Variable ID
# ged_ns_best_sum_nokgi  The best (most likely) estimate of the total n...
# ged_os_best_sum_nokgi  The best (most likely) estimate of the total n...
# ged_sb_best_sum_nokgi  The best (most likely) estimate of the total n...
# wdi_ag_lnd_frst_k2     Forest area is land under natural or planted s...
# wdi_ny_gdp_mktp_kd     GDP at purchaser's prices is the sum of gross ...
# wdi_ms_mil_xpnd_gd_zs  Military expenditures data from SIPRI are deri...
# wdi_ms_mil_xpnd_zs     Military expenditures data from SIPRI are deri...
# wdi_dt_oda_odat_pc_zs  Net official development assistance (ODA) per ...
# wdi_nv_agr_totl_kd     Agriculture, forestry, and fishing corresponds...
# wdi_nv_agr_totl_kn     Agriculture, forestry, and fishing corresponds...
# wdi_sp_pop_totl        Total population is based on the de facto defi...
#
# Subcolumn             Periodicity  \
# Variable ID
# ged_ns_best_sum_nokgi     Monthly
# ged_os_best_sum_nokgi     Monthly
# ged_sb_best_sum_nokgi     Monthly
# wdi_ag_lnd_frst_k2         Annual
# wdi_ny_gdp_mktp_kd         Annual
# wdi_ms_mil_xpnd_gd_zs      Annual
# wdi_ms_mil_xpnd_zs         Annual
# wdi_dt_oda_odat_pc_zs      Annual
# wdi_nv_agr_totl_kd         Annual
# wdi_nv_agr_totl_kn         Annual
# wdi_sp_pop_totl            Annual
#
# Subcolumn                                              Short description  \
# Variable ID
# ged_ns_best_sum_nokgi  The best (most likely) estimate of the total n...
# ged_os_best_sum_nokgi  The best (most likely) estimate of the total n...
# ged_sb_best_sum_nokgi  The best (most likely) estimate of the total n...
# wdi_ag_lnd_frst_k2                                  Forest area (sq. km)
# wdi_ny_gdp_mktp_kd                          GDP per capita (current LCU)
# wdi_ms_mil_xpnd_gd_zs                  Military expenditure as % of GDP.
# wdi_ms_mil_xpnd_zs     Military expenditure as % of general governmen...
# wdi_dt_oda_odat_pc_zs  Net official development assistance (ODA) rece...
# wdi_nv_agr_totl_kd     Value added from agriculture in constant 2015 ...
# wdi_nv_agr_totl_kn     Value added from agriculture in constant local...
# wdi_sp_pop_totl                                      Population in total
#
# Subcolumn                                                         Source  \
# Variable ID
# ged_ns_best_sum_nokgi  UCDP Georeferenced Events Dataset (UCDP GED) a...
# ged_os_best_sum_nokgi  UCDP Georeferenced Events Dataset (UCDP GED) a...
# ged_sb_best_sum_nokgi  UCDP Georeferenced Events Dataset (UCDP GED) a...
# wdi_ag_lnd_frst_k2     World Bank. "XXX". World Development Indicator...
# wdi_ny_gdp_mktp_kd     World Bank. "GDP (constant 2015 US$)". World D...
# wdi_ms_mil_xpnd_gd_zs  World Bank. "Military expenditure (% of GDP)"....
# wdi_ms_mil_xpnd_zs     World Bank. "Military expenditure (% of genera...
# wdi_dt_oda_odat_pc_zs  World Bank. "Net ODA received per capita (curr...
# wdi_nv_agr_totl_kd     World Bank. "XXX". World Development Indicator...
# wdi_nv_agr_totl_kn     World Bank. "XXX". World Development Indicator...
# wdi_sp_pop_totl        World Bank. "Population, total." World Develop...
#
# Subcolumn                        Transformations prior to data ingestion  \
# Variable ID
# ged_ns_best_sum_nokgi  Nokgi = No imputation (single or multiple) was...
# ged_os_best_sum_nokgi  Nokgi = No imputation (single or multiple) was...
# ged_sb_best_sum_nokgi  Nokgi = No imputation (single or multiple) was...
# wdi_ag_lnd_frst_k2                           clean-up, iso codes created
# wdi_ny_gdp_mktp_kd                           clean-up, iso codes created
# wdi_ms_mil_xpnd_gd_zs                        clean-up, iso codes created
# wdi_ms_mil_xpnd_zs                           clean-up, iso codes created
# wdi_dt_oda_odat_pc_zs                        clean-up, iso codes created
# wdi_nv_agr_totl_kd                           clean-up, iso codes created
# wdi_nv_agr_totl_kn                           clean-up, iso codes created
# wdi_sp_pop_totl                              clean-up, iso codes created
#
# Subcolumn             Viewser table
# Variable ID
# ged_ns_best_sum_nokgi       ged2_cm
# ged_os_best_sum_nokgi       ged2_cm
# ged_sb_best_sum_nokgi       ged2_cm
# wdi_ag_lnd_frst_k2           wdi_cy
# wdi_ny_gdp_mktp_kd           wdi_cy
# wdi_ms_mil_xpnd_gd_zs        wdi_cy
# wdi_ms_mil_xpnd_zs           wdi_cy
# wdi_dt_oda_odat_pc_zs        wdi_cy
# wdi_nv_agr_totl_kd           wdi_cy
# wdi_nv_agr_totl_kn           wdi_cy
# wdi_sp_pop_totl              wdi_cy

# %%
# set formatting options
float_format = "%.2f"
num_align = "right"
str_align = "left"

# generate markdown table
md_table = df2.to_markdown(floatfmt=float_format, numalign=num_align, stralign=str_align)

# print markdown table
#print(md_table)

# %%
json_file = df2.to_json(orient="index")

json_file

# %%
df2.to_json('test2.json', orient='records')
